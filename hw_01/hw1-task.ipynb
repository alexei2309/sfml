# %%
import pandas as pd

# %%
# (1) Используя параметры pandas прочитать красиво пандас (подвох что заголовки - первые 2 линии)
df = pd.read_csv ('default_of_credit_card_clients.csv',sep=';') #TODO

# %%
df.head(5)
df.loc [1:].head()
#df.columns = df.iloc[0]  #разобрался уже в конце как изменить заголовки
df
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26     -1      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# 5              5      50000    1          2         1   57     -1      0
# 6              6      50000    1          1         2   37      0      0
# 7              7     500000    1          1         2   29      0      0
# 8              8     100000    2          2         2   23      0     -1
# 9              9     140000    2          3         1   28      0      0
# 10            10      20000    1          3         2   35     -2     -2
# 11            11     200000    2          3         2   34      0      0
# ...

# %%
# (2) выведите, что за типы переменных, сколько пропусков,
# для численных значений посчитайте пару статистик (в свободной форме)

# %%
#TODO
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 25 columns):
# Unnamed: 0    30001 non-null object
# X1            30001 non-null object
# X2            30001 non-null object
# X3            30001 non-null object
# X4            30001 non-null object
# X5            30001 non-null object
# X6            30001 non-null object
# X7            30001 non-null object
# X8            30001 non-null object
# X9            30001 non-null object
# X10           30001 non-null object
# X11           30001 non-null object
# X12           30001 non-null object
# X13           30001 non-null object
# X14           30001 non-null object
# X15           30001 non-null object
# X16           30001 non-null object
# X17           30001 non-null object
# X18           30001 non-null object
# X19           30001 non-null object
# X20           30001 non-null object
# X21           30001 non-null object
# X22           30001 non-null object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0     X1     X2     X3     X4     X5     X6     X7     X8  \
# count       30001  30001  30001  30001  30001  30001  30001  30001  30001
# unique      30001     82      3      8      5     57     12     12     12
# top         23677  50000      2      2      2     29      0      0      0
# freq            1   3365  18112  14030  15964   1605  14737  15730  15764
#
#            X9  ...      X15    X16    X17    X18    X19    X20    X21    X22  \
# count   30001  ...    30001  30001  30001  30001  30001  30001  30001  30001
# unique     12  ...    21549  21011  20605   7944   7900   7519   6938   6898
# top         0  ...        0      0      0      0      0      0      0      0
# freq    16455  ...     3195   3506   4020   5249   5396   5968   6408   6703
#
#           X23      Y
# count   30001  30001
# unique   6940      3
# top         0      0
# freq     7173  23364
#
# [4 rows x 25 columns]

# %%
df ['X1'].map(len).head()
# Out:
# 0    9
# 1    5
# 2    6
# 3    5
# 4    5
# Name: X1, dtype: int64

# %%
#посчитать
df [['Unnamed: 0','X1']].groupby('X1').count ().head ()
# Out:
#          Unnamed: 0
# X1
# 10000           493
# 100000         1048
# 1000000           1
# 110000          588
# 120000          726

# %%
# (3) посчитать число женщин с университетским образованием
# SEX (1 = male; 2 = female). 
# EDUCATION (1 = graduate school; 2 = university; 3 = high school; 4 = others). 
tmp=df [df ['X2'].isin (['2']) & (df ['X3']=='2')]
tmp[['X2','X3']].groupby('X2').count ()
#TODO
# Out:
#       X3
# X2
# 2   8656

# %%
# (3) вариант 2 
tmp=df [df ['X2'].isin (['2']) & (df ['X3']=='2')].count ()
tmp.describe()
# Out:
# count      25.0
# mean     8656.0
# std         0.0
# min      8656.0
# 25%      8656.0
# 50%      8656.0
# 75%      8656.0
# max      8656.0
# dtype: float64

# %%
# (4) Сгрупировать по "default payment next month" и посчитать медиану для всех показателей начинающихся на BILL_ и PAY_
#TODO

#df.loc [:1].head().T  #транспонируем, смотрим поля
df=df.loc[1:,'X6':'Y']#проверяем, что корректно выгружены поля
df=df.astype ('int')
#df.info()  #проверяем изменение типа данных
df [['X12','X13','X14','X15','X16','X17','X18','X19','X20','X21','X22','X23','Y']].groupby('Y').median ()
# Out:
#        X12      X13      X14      X15      X16      X17     X18     X19  \
# Y
# 0  23119.5  21660.5  20202.5  19000.0  17998.0  16679.0  2459.5  2247.5
# 1  20185.0  20300.5  19834.5  19119.5  18478.5  18028.5  1636.0  1533.5
#
#       X20     X21     X22     X23
# Y
# 0  2000.0  1734.0  1765.0  1706.0
# 1  1222.0  1000.0  1000.0  1000.0

# %%
# (5) постройте сводную таблицу (pivot table) по SEX, EDUCATION, MARRIAGE
df = pd.read_csv ('default_of_credit_card_clients.csv',sep=';')
df=df.loc[1:]
#df=df.astype ('str')
#df.info()
df.pivot_table ('X2','X3','X4','count')
# Out:
# X4     0       1       2      3
# X3
# 0    NaN     4.0    10.0    NaN
# 1    4.0  3722.0  6809.0   50.0
# 2    6.0  6842.0  7020.0  162.0
# 3   44.0  2861.0  1909.0  103.0
# 4    NaN    52.0    68.0    3.0
# 5    NaN   150.0   127.0    3.0
# 6    NaN    28.0    21.0    2.0

# %%
# (6) Создать новый строковый столбец в data frame-е, который:
# принимает значение A, если значение LIMIT_BAL <=10000
# принимает значение B, если значение LIMIT_BAL <=100000 и >10000
# принимает значение C, если значение LIMIT_BAL <=200000 и >100000
# принимает значение D, если значение LIMIT_BAL <=400000 и >200000
# принимает значение E, если значение LIMIT_BAL <=700000 и >400000
# принимает значение F, если значение LIMIT_BAL >700000

#TODO
df = pd.read_csv ('default_of_credit_card_clients.csv',sep=';')
df=df.loc [1:]
#df
df['X1']=df['X1'].astype('int')
#df.info()
   
#df['X1']
def limit (s):
    if s <=10000:
        return 'A'
    elif s <=100000 and s >10000:
        return 'B'
    elif s <=200000 and s >100000:
        return 'C'
    elif s <=400000 and s >20000:
        return 'D'
    elif s <=700000 and s >40000:
        return 'E'
    elif  s >700000:
        return 'F'
    else: 
        return 'unknown'
df['X50']=df['X1'].map(limit)
df.head()
# Out:
#   Unnamed: 0      X1 X2 X3 X4  X5  X6 X7  X8  X9 ...    X16    X17   X18  \
# 1          1   20000  2  2  1  24   2  2  -1  -1 ...      0      0     0
# 2          2  120000  2  2  2  26  -1  2   0   0 ...   3455   3261     0
# 3          3   90000  2  2  2  34   0  0   0   0 ...  14948  15549  1518
# 4          4   50000  2  2  1  37   0  0   0   0 ...  28959  29547  2000
# 5          5   50000  1  2  1  57  -1  0  -1   0 ...  19146  19131  2000
#
#      X19    X20   X21   X22   X23  Y X50
# 1    689      0     0     0     0  1   B
# 2   1000   1000  1000     0  2000  1   C
# 3   1500   1000  1000  1000  5000  0   B
# 4   2019   1200  1100  1069  1000  0   B
# 5  36681  10000  9000   689   679  0   B
#
# [5 rows x 26 columns]

# %%
# %matplotlib inline

# %%
# (7) постироить распределение LIMIT_BAL (гистрограмму)
df [~df['X1'].isnull()]['X1'].hist (bins=15)

# %%
import seaborn as sns
from  matplotlib import pyplot as plt

# %%
df.head() #TODO
#df
fig, ax =plt.subplots(figsize=(60,20))
df.pivot_table ('X1','X3','X2','count').plot(kind='bar',stacked=False,ax=ax)

# %%
# (8) построить зависимость кредитного лимита от образования для каждого пола
# график необходимо сделать очень широким (на весь экран)
df.head() #TODO
# Out:
#   Unnamed: 0      X1 X2 X3 X4  X5  X6 X7  X8  X9 ...    X16    X17   X18  \
# 1          1   20000  2  2  1  24   2  2  -1  -1 ...      0      0     0
# 2          2  120000  2  2  2  26  -1  2   0   0 ...   3455   3261     0
# 3          3   90000  2  2  2  34   0  0   0   0 ...  14948  15549  1518
# 4          4   50000  2  2  1  37   0  0   0   0 ...  28959  29547  2000
# 5          5   50000  1  2  1  57  -1  0  -1   0 ...  19146  19131  2000
#
#      X19    X20   X21   X22   X23  Y X50
# 1    689      0     0     0     0  1   B
# 2   1000   1000  1000     0  2000  1   C
# 3   1500   1000  1000  1000  5000  0   B
# 4   2019   1200  1100  1069  1000  0   B
# 5  36681  10000  9000   689   679  0   B
#
# [5 rows x 26 columns]

# %%
# (9) построить зависимость кредитного лимита и образования только для одного из полов

#TODO
tmp=df [df ['X2']=='2']
tmp
tmp.pivot_table ('X1','X3','X2','count').plot(kind='bar',stacked=False)

# %%
# (10) построить большой график (подсказка - используя seaborn) для построения завимисости всех возможных пар параметров
# разным цветом выделить разные значение "default payment next month"
# (но так как столбцов много - картинка может получиться "монструозной")
# (поэкспериментируйте над тем как построить подобное сравнение параметров)
# (подсказка - ответ может состоять из несколькольких графиков)
# (если не выйдет - программа минимум - построить один график со всеми параметрами)
import seaborn
import pandas as pd
#TODO

# %%
df = pd.read_csv ('default_of_credit_card_clients.csv',sep=';')

# %%
df.columns = df.iloc[0]  #разобрался уже в конце как изменить заголовки
df.head()
# Out:
# 0  ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0  ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 1   1      20000    2          2         1   24      2      2     -1     -1
# 2   2     120000    2          2         2   26     -1      2      0      0
# 3   3      90000    2          2         2   34      0      0      0      0
# 4   4      50000    2          2         1   37      0      0      0      0
#
# 0             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1
# 1             ...                      0          0          0         0
# 2             ...                   3272       3455       3261         0
# 3             ...                  14331      14948      15549      1518
# 4             ...                  28314      28959      29547      2000
#
# 0  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
df.loc [1:].head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 25 columns):
# ID                            30001 non-null object
# LIMIT_BAL                     30001 non-null object
# SEX                           30001 non-null object
# EDUCATION                     30001 non-null object
# MARRIAGE                      30001 non-null object
# AGE                           30001 non-null object
# PAY_0                         30001 non-null object
# PAY_2                         30001 non-null object
# PAY_3                         30001 non-null object
# PAY_4                         30001 non-null object
# PAY_5                         30001 non-null object
# PAY_6                         30001 non-null object
# BILL_AMT1                     30001 non-null object
# BILL_AMT2                     30001 non-null object
# BILL_AMT3                     30001 non-null object
# BILL_AMT4                     30001 non-null object
# ...

# %%
p=df[['LIMIT_BAL','SEX','EDUCATION','MARRIAGE']].head()

# %%
tmp=p.iloc[1:].head()
tmp2=tmp.astype('int')

# %%
tmp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 1 to 4
# Data columns (total 4 columns):
# LIMIT_BAL    4 non-null int32
# SEX          4 non-null int32
# EDUCATION    4 non-null int32
# MARRIAGE     4 non-null int32
# dtypes: int32(4)
# memory usage: 148.0 bytes

# %%
sns.pairplot (tmp2,hue='SEX')
